# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarsis1/ETL-com-python---Tarsis/blob/main/ETL_com_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as srn
import statistics  as sts

# %%
path = "https://drive.google.com/uc?export=download&id=1gDtBRsFxe3ySm6YmT8SLOMeifnYF-TkI"
dataset = pd.read_csv(path, sep=";")

# %%
dataset.head()
# Out:
#    X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0   1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1   2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2   3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3   4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4   5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0

# %%
#Nomeando as colunas
dataset.columns = ["Id","Score","Estado","Genero","Idade","Patrimonio","Saldo","Produtos","TemCartCredito","Ativo","Salario","Saiu"]

# %%
#Valores nulos
dataset.isnull().sum()
# Out:
# Id                0
# Score             0
# Estado            0
# Genero            8
# Idade             0
# Patrimonio        0
# Saldo             0
# Produtos          0
# TemCartCredito    0
# Ativo             0
# Salario           7
# Saiu              0
# dtype: int64

# %%
#Subsituindo pela mediana em Salarios
mediana = sts.median(dataset['Salario'])
mediana
# Out:
# 70518.0

# %%
dataset['Salario'].fillna(mediana, inplace=True)

# %%
dataset['Salario'].isnull().sum()
# Out:
# 0

# %%
#Agrupar variaveis iguais mais escritas diferentes
agrupado = dataset.groupby(['Genero']).size()
agrupado
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
dataset['Genero'].fillna('Masculino', inplace=True)

dataset['Genero'].isnull().sum()
# Out:
# 0

# %%
dataset.loc[dataset['Genero'] ==  'M', 'Genero'] = "Masculino"
dataset.loc[dataset['Genero'].isin( ['Fem','F']), 'Genero'] = "Feminino"
#visualiza o resultado
agrupado = dataset.groupby(['Genero']).size()
agrupado
# Out:
# Genero
# Feminino     464
# Masculino    535
# dtype: int64

# %%
#substituir idades fora do padrão pela mediana
dataset['Idade'].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
dataset.loc[(dataset['Idade'] <  0 )  | ( dataset['Idade'] >  120) ]
# Out:
#       Id  Score Estado     Genero  Idade  Patrimonio     Saldo  Produtos  \
# 867  869    636     RS   Feminino    -10           1  17083346         1
# 984  986    773     RS  Masculino    -20           1  12453278         2
# 990  992    655     RS  Masculino    140           5     93147         2
#
#      TemCartCredito  Ativo     Salario  Saiu
# 867               1      0  11051028.0     1
# 984               0      1   1172357.0     0
# 990               1      0   6621413.0     0

# %%
mediana = sts.median(dataset['Idade'])
mediana
# Out:
# 37

# %%
dataset.loc[(dataset['Idade'] <  0 )  | ( dataset['Idade'] >  120), 'Idade'] = mediana

# %%
dataset[dataset.duplicated(['Id'],keep=False)]
# Out:
#     Id  Score Estado    Genero  Idade  Patrimonio    Saldo  Produtos  \
# 80  81    665     RS  Feminino     34           1  9664554         2
# 81  81    665     RS  Feminino     34           1  9664554         2
#
#     TemCartCredito  Ativo     Salario  Saiu
# 80               0      0  17141366.0     0
# 81               0      0  17141366.0     0

# %%
dataset.drop_duplicates(subset="Id", keep='first',inplace=True)

# %%
dataset.head()
# Out:
#    Id  Score Estado    Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TemCartCredito  Ativo     Salario  Saiu
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0
